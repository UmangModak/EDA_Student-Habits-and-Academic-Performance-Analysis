# %% [markdown]
# ### Problem Statement : We need to check the exam score of a student onthe basis of following activities:
# 'student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation

# %%
import numpy as np  # to perform calculative operation and perform awith arrays
import pandas as pd  # pandas is for analysis
import matplotlib.pyplot as plt # visualization libraryr
import seaborn as sns

# %%
df = pd.read_csv(r"E:\student_habits_performance.csv") # loadt the dataset

# %%
df = pd.read_csv("student_habits_performance.csv")

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
# 5      S1005   24    Male                  7.2                 1.3
# 6      S1006   21  Female                  5.6                 1.5
# 7      S1007   21  Female                  4.3                 1.0
# 8      S1008   23  Female                  4.4                 2.2
# 9      S1009   18  Female                  4.8                 3.1
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# ...

# %%
df.tail(10)
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 990      S1990   18    Male                  3.2                 3.5
# 991      S1991   20    Male                  6.0                 2.1
# 992      S1992   18    Male                  3.5                 0.0
# 993      S1993   20    Male                  3.8                 2.1
# 994      S1994   20  Female                  1.6                 1.3
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 990            1.7            No                   91.7          6.5
# ...

# %%
df.shape # rows and columns present in out dataset
# Out:
# (1000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.isnull().head(40) # it checks the null value
# Out:
#     student_id    age  gender  study_hours_per_day  social_media_hours  \
# 0        False  False   False                False               False
# 1        False  False   False                False               False
# 2        False  False   False                False               False
# 3        False  False   False                False               False
# 4        False  False   False                False               False
# 5        False  False   False                False               False
# 6        False  False   False                False               False
# 7        False  False   False                False               False
# 8        False  False   False                False               False
# 9        False  False   False                False               False
# 10       False  False   False                False               False
# 11       False  False   False                False               False
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.dropna()
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df['parental_education_level'].dtypes
# Out:
# dtype('O')

# %%
x = df['parental_education_level'].mode([0])

# %%
df.fillna(x,inplace=True)

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
#   df['parental_education_level'] = df['parental_education_level'].astype('int')

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.isnull().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.rename(columns = {'study_hours_per_day':'study_hours'},inplace=True)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age  study_hours  social_media_hours  netflix_hours  \
# count  909.000000   909.000000          909.000000     909.000000
# mean    20.475248     3.538724            2.504620       1.830363
# std      2.302721     1.469730            1.164802       1.071251
# min     17.000000     0.000000            0.000000       0.000000
# 25%     18.000000     2.500000            1.700000       1.000000
# 50%     20.000000     3.500000            2.500000       1.800000
# 75%     22.000000     4.500000            3.300000       2.600000
# max     24.000000     8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# ...

# %%
# Data cleaning  and data filling part

# %% [markdown]
# # EDA : Exploratory data analysis : EDA, or Exploratory Data Analysis, is a crucial first step in data analysis where you use visualization and statistical methods to understand a dataset's main characteristics, detect anomalies, and identify relationships between variables.

# %% [markdown]
#  1.Univariant Analysis :it is use to plot or visuals  withn one columns.
#  2.Multivarient Analysis  / Bivariant : it has mmultiple input

# %% [markdown]
# ## UNivariant analysis

# %%
a = sns.countplot(x='gender',data=df)
plt.figure(figsize=(12,6))
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# from the above graph we can see that the total number of male ,female and other are follows as 440 , 433 and 36 . we can see that the male count / percentage is slightly higher than female and other.

# %%
a= sns.countplot(x='age',data= df,hue='gender')
plt.figure(figsize=(12,10))

for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# from the above graph it is clearly shown that the 20 age group has the highest participant  containing male = 60 , female 70 and other = 7
# the female participant is slighlyt higher in mostly age group.

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
a = sns.countplot(x='internet_quality',data=df)
plt.figure(figsize=(12,6))
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# mostly student have good quality of internet

# %%
a = sns.countplot(x='parental_education_level',data=df)
plt.figure(figsize=(12,6))
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# we can understand from the above graph the mostly parents have high school degree or bachlor's degree

# %%
a = sns.countplot(x='mental_health_rating',data=df)
plt.figure(figsize=(12,6))
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# from the above graph we can say that the 4 have the maximum count of student mental rating .
# 4 > 6 and 8 >1 and 10

# %%
a = sns.countplot(x='extracurricular_participation',data=df)
plt.figure(figsize=(12,6))
for bars in a.containers:
    a.bar_label(bars)

# %% [markdown]
# moslty student dont have any extra curricular activities apart from study  and chill hrs

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %% [markdown]
# ### Bivariant analysis : Two inputs

# %%
a = sns.barplot(x='gender' ,y= 'age', data=df)
for bars in a.containers:
    a.bar_label(bars)

# %%
sns.scatterplot(x='study_hours' ,y= 'exam_score', data=df)
# Out:
# <Axes: xlabel='study_hours', ylabel='exam_score'>

# %% [markdown]
# Those student who study for atleast 2 - 6 hours they have good exam  score.
# 4 hrs per have score in the range of 50-90
# 5, 6 hr study per day  very few student have score more than 60
# those who study 8 hrs per day they score above 100 and very few student has achived that.

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours', 'social_media_hours',
#        'netflix_hours', 'part_time_job', 'attendance_percentage',
#        'sleep_hours', 'diet_quality', 'exercise_frequency',
#        'parental_education_level', 'internet_quality', 'mental_health_rating',
#        'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
sns.barplot(x='social_media_hours',y='gender',data=df)
# Out:
# <Axes: xlabel='social_media_hours', ylabel='gender'>

# %%
sns.scatterplot(x='social_media_hours',y='exam_score',data=df)
# Out:
# <Axes: xlabel='social_media_hours', ylabel='exam_score'>

# %% [markdown]
# from the above graphs we can say that those who stays on social media have less number of marks .

# %%
sns.barplot(x='part_time_job',y='exam_score',data=df)
# Out:
# <Axes: xlabel='part_time_job', ylabel='exam_score'>

# %% [markdown]
# ### Conclusion :  Those student have scrolling or staying on social media for the number of hours have less exam score campared to those who dont spend time to much of social media. those who study 4 hours per day have good score and those hwho study more than that are getting excellent score. those student who are doing part time job , they are not affecting their studies whihc means they are balancing their study and job.
